# %% [markdown]
# <a href="https://colab.research.google.com/github/clementina-tom/Primary-competition-visual-DigiCow-Farmer-Training-Adoption-Challenge/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import zipfile
import os

zip_file_path = '/content/digicow-farmer-training-adoption-challenge20260210-32396-19ubatl.zip'
extract_dir = '/content/digicow_data'

# Create the directory if it doesn't exist
os.makedirs(extract_dir, exist_ok=True)

# Unzip the file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_dir)

print(f"File extracted to: {extract_dir}")

# List the contents of the extracted directory to confirm
print("Contents of extracted directory:")
for root, dirs, files in os.walk(extract_dir):
    for name in files:
        print(os.path.join(root, name))
    for name in dirs:
        print(os.path.join(root, name))
# Out:
# File extracted to: /content/digicow_data
# Contents of extracted directory:
# /content/digicow_data/Train.csv
# /content/digicow_data/dataset_data_dictionary.csv
# /content/digicow_data/manifest-065f681d7bfda0fad5e1c34e0c2951fc20260210-32396-1gsnoi9.json
# /content/digicow_data/StarterNotebook.ipynb
# /content/digicow_data/SampleSubmission.csv
# /content/digicow_data/Test.csv
# /content/digicow_data/Prior.csv

# %%
import pandas as pd
import numpy as np
from lightgbm import LGBMClassifier

# 1. Train 3 separate models for each time horizon
model_07 = LGBMClassifier(n_estimators=300, learning_rate=0.05)
model_90 = LGBMClassifier(n_estimators=300, learning_rate=0.05)
model_120 = LGBMClassifier(n_estimators=300, learning_rate=0.05)

# Assuming X_train, X_test, y_07, y_90, y_120 are already defined
model_07.fit(X_train, y_07)
model_90.fit(X_train, y_90)
model_120.fit(X_train, y_120)

# 2. Extract the probability of class 1 (Adoption)
p_07 = model_07.predict_proba(X_test)[:, 1]
p_90 = model_90.predict_proba(X_test)[:, 1]
p_120 = model_120.predict_proba(X_test)[:, 1]

# 3. Post-processing to enforce logical cumulative adoption
p_90 = np.maximum(p_07, p_90)
p_120 = np.maximum(p_90, p_120)

# 4. Format for Zindi Evaluation (Duplicating the probability columns)
submission = pd.DataFrame({
    'ID': test_df['ID'],
    'Target_07_AUC': p_07,
    'Target_07_LogLoss': p_07,
    'Target_90_AUC': p_90,
    'Target_90_LogLoss': p_90,
    'Target_120_AUC': p_120,
    'Target_120_LogLoss': p_120
})

submission.to_csv('my_digicow_submission.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2264232611.py in <cell line: 0>()
#       9
#      10 # Assuming X_train, X_test, y_07, y_90, y_120 are already defined
# ---> 11 model_07.fit(X_train, y_07)
#      12 model_90.fit(X_train, y_90)
#      13 model_120.fit(X_train, y_120)
#
# NameError: name 'X_train' is not defined

# %% [markdown]
# *   List item
# *   List item

# %%
import pandas as pd
import numpy as np

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.metrics import average_precision_score, roc_auc_score
from sklearn.linear_model import LogisticRegression

# %%
## Loading the data
train_df = pd.read_csv('/content/digicow_data/Train.csv')
test_df = pd.read_csv('/content/digicow_data/Test.csv')
#y_true = pd.read_csv('reference.csv')['Target_AUC'] # This file was not found in extracted data, keeping commented.

# train_df_ = pd.read_csv('Train_.csv') # Commenting out as 'Train_.csv' was not found in the unzipped files
# test_df_ = pd.read_csv('Test_.csv')   # Commenting out as 'Test_.csv' was not found in the unzipped files
#y_true_ = pd.read_csv('reference_.csv')['Target_AUC'] # This file was not found in extracted data, keeping commented.

# %%
for c in [col for col in train_df.columns if col.endswith('date')]:
  if c in train_df.columns:
    train_df[c] = pd.to_datetime(train_df[c], errors='coerce')

# for c in [col for col in train_df_.columns if col.endswith('date')]:
#   if c in train_df_.columns:
#     train_df_[c] = pd.to_datetime(train_df_[c], errors='coerce')

# %%
target_col = 'adopted_within_07_days'
train_df[target_col] = train_df[target_col].astype(int)

# target_col = 'adopted_within_07_days'
# train_df_[target_col] = train_df_[target_col].astype(int)

# %%
for c in [col for col in test_df.columns if col.endswith('date')]:
  if c in test_df.columns:
    test_df[c] = pd.to_datetime(test_df[c], errors='coerce')


# for c in [col for col in test_df_.columns if col.endswith('date')]:
#   if c in test_df_.columns:
#     test_df_[c] = pd.to_datetime(test_df_[c], errors='coerce')

# %%
split_summary = pd.DataFrame({
    "set": ["train"],
    "rows": [len(train_df)],
    "positives": [train_df[target_col].sum()],
})
split_summary["pos_rate"] = split_summary["positives"] / split_summary["rows"]

split_summary
# Out:
#      set   rows  positives  pos_rate
# 0  train  13536        153  0.011303

# %%
# split_summary_ = pd.DataFrame({
#     "set": ["train"],
#     "rows": [len(train_df_)],
#     "positives": [train_df_[target_col].sum()],
# })
# split_summary_["pos_rate"] = split_summary_["positives"] / split_summary_["rows"]

# split_summary_

# %%
## Basic model with some selected features
base_features = [
    "gender",
    "registration",
    "age",
    "trainer",
    "belong_to_cooperative",
    "county",
    "subcounty",
    "ward",
]

# %%
feature_cols = base_features

X_train = train_df[feature_cols]
y_train = train_df[target_col]

X_test  = test_df[feature_cols]


#X_train_ = train_df_[feature_cols]
#y_train_ = train_df_[target_col]

#X_test_  = test_df_[feature_cols]

# %% [markdown]
# ## Make the prediction

# %%
preprocess = ColumnTransformer(
    transformers=[
        ("cat", Pipeline(steps=[
            ("imputer", SimpleImputer(strategy="most_frequent")),
            ("ohe", OneHotEncoder(handle_unknown="ignore"))
        ]), feature_cols)
    ]
)

model = Pipeline(steps=[
    ("preprocess", preprocess),
    ("clf", LogisticRegression(max_iter=3000, class_weight="balanced"))
])

model.fit(X_train, y_train)
y_pred_prob = model.predict_proba(X_test)[:, 1]
y_pred = model.predict(X_test)

# %%
preprocess_ = ColumnTransformer(
    transformers=[
        ("cat", Pipeline(steps=[
            ("imputer", SimpleImputer(strategy="most_frequent")),
            ("ohe", OneHotEncoder(handle_unknown="ignore"))
        ]), feature_cols)
    ]
)

model_ = Pipeline(steps=[
    ("preprocess", preprocess_),
    ("clf", LogisticRegression(max_iter=3000, class_weight="balanced"))
])

# model_.fit(X_train_, y_train_)
# y_pred_prob_ = model.predict_proba(X_test_)[:, 1]
# y_pred_ = model_.predict(X_test_)

# %%
y_pred
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
## Evaluating some metrics
# ----------------------------
#  Metrics: PR AUC + ROC AUC + Recall@K
# ----------------------------
def recall_at_k(y_true: pd.Series, y_scores: np.ndarray, k_frac: float) -> float:
    k = int(np.ceil(len(y_true) * k_frac))
    order = np.argsort(-y_scores)  # descending
    topk = order[:k]
    return float(y_true.iloc[topk].sum() / y_true.sum()) if y_true.sum() > 0 else np.nan

# %%
# pr_auc = average_precision_score(y_true, y_pred_prob)
# roc_auc = roc_auc_score(y_true, y_pred_prob)
# recall_5 = recall_at_k(y_true, y_pred_prob, 0.05)
# recall_10 = recall_at_k(y_true, y_pred_prob, 0.10)
# recall_20 = recall_at_k(y_true, y_pred_prob, 0.20)

# # Naive baselines on this test set
# prevalence_test = y_true.mean()
# naive_pr_auc = prevalence_test

# results = pd.DataFrame({
#     "metric": [
#         "PR AUC (Average Precision)",
#         "ROC AUC",
#         "Recall@5%",
#         "Recall@10%",
#         "Recall@20%",
#         "Naive PR AUC (prevalence)",
#     ],
#     "value": [pr_auc, roc_auc, recall_5, recall_10, recall_20, naive_pr_auc]
# })


print("\nSplit summary:")
display(split_summary)
# print("\nResults:")
# display(results)
# Out:
# Split summary:
#      set   rows  positives  pos_rate
# 0  train  13536        153  0.011303

# %%
## Evaluating some metrics
# ----------------------------
#  Metrics: PR AUC + ROC AUC + Recall@K
# ----------------------------
def recall_at_k(y_true: pd.Series, y_scores: np.ndarray, k_frac: float) -> float:
    k = int(np.ceil(len(y_true) * k_frac))
    order = np.argsort(-y_scores)  # descending
    topk = order[:k]
    return float(y_true.iloc[topk].sum() / y_true.sum()) if y_true.sum() > 0 else np.nan

# %%
y_pred_prob
# Out:
# array([7.02321817e-04, 3.87966064e-03, 8.40725890e-01, ...,
#        7.02321817e-04, 7.02321817e-04, 7.02321817e-04])

# %%
y_pred
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
'''pr_auc_ = average_precision_score(y_true_, y_pred_prob_)
roc_auc_ = roc_auc_score(y_true_, y_pred_prob_)
recall_5_ = recall_at_k(y_true_, y_pred_prob_, 0.05)
recall_10_ = recall_at_k(y_true_, y_pred_prob_, 0.10)
recall_20_ = recall_at_k(y_true_, y_pred_prob_, 0.20)

# Naive baselines on this test set
prevalence_test_ = y_true_.mean()
naive_pr_auc_ = prevalence_test_

results_ = pd.DataFrame({
    "metric": [
        "PR AUC (Average Precision)",
        "ROC AUC",
        "Recall@5%",
        "Recall@10%",
        "Recall@20%",
        "Naive PR AUC (prevalence)",
    ],
    "value": [pr_auc_, roc_auc_, recall_5_, recall_10_, recall_20_, naive_pr_auc_]
})


print("\nSplit summary:")
display(split_summary_)
print("\nResults:")
display(results_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-241690345.py in <cell line: 0>()
# ----> 1 pr_auc_ = average_precision_score(y_true_, y_pred_prob_)
#       2 roc_auc_ = roc_auc_score(y_true_, y_pred_prob_)
#       3 recall_5_ = recall_at_k(y_true_, y_pred_prob_, 0.05)
#       4 recall_10_ = recall_at_k(y_true_, y_pred_prob_, 0.10)
#       5 recall_20_ = recall_at_k(y_true_, y_pred_prob_, 0.20)
#
# NameError: name 'y_true_' is not defined

# %%
## Make submission file
ss = pd.read_csv('/content/digicow_data/SampleSubmission.csv')
ss['Target_LogLoss'] = y_pred_prob
ss['Target_AUC'] = y_pred_prob
ss.to_csv('BenchmarkSub.csv', index=False)

'''
ss_ = pd.read_csv('SampleSubmission_.csv')
ss_['Target_LogLoss'] = y_pred_prob_
ss_['Target_AUC'] = y_pred_prob_
'''
# ss_.to_csv('BenchmarkSub_.csv', index=False)
# Out:
# "\nss_ = pd.read_csv('SampleSubmission_.csv')\nss_['Target_LogLoss'] = y_pred_prob_\nss_['Target_AUC'] = y_pred_prob_\n"

# %%
ss.head()
# Out:
#           ID  Target_07_AUC  Target_90_AUC  Target_120_AUC  Target_07_LogLoss  \
# 0  ID_LEG1GM              0              0               0                  0
# 1  ID_1UKOKW              0              0               0                  0
# 2  ID_U5H2YK              0              0               0                  0
# 3  ID_55957A              0              0               0                  0
# 4  ID_N1AC0A              0              0               0                  0
#
#    Target_90_LogLoss  Target_120_LogLoss  Target_LogLoss  Target_AUC
# 0                  0                   0        0.000702    0.000702
# 1                  0                   0        0.003880    0.003880
# 2                  0                   0        0.840726    0.840726
# 3                  0                   0        0.628535    0.628535
# 4                  0                   0        0.003471    0.003471

# %%
ss_.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-978668125.py in <cell line: 0>()
# ----> 1 ss_.head()
#
# NameError: name 'ss_' is not defined

# %%
ss
# Out:
#              ID  Target_07_AUC  Target_90_AUC  Target_120_AUC  \
# 0     ID_LEG1GM              0              0               0
# 1     ID_1UKOKW              0              0               0
# 2     ID_U5H2YK              0              0               0
# 3     ID_55957A              0              0               0
# 4     ID_N1AC0A              0              0               0
# ...         ...            ...            ...             ...
# 5616  ID_L8T6ZB              0              0               0
# 5617  ID_D1SBOO              0              0               0
# 5618  ID_83M5MJ              0              0               0
# 5619  ID_XOU76K              0              0               0
# 5620  ID_IWZ84Z              0              0               0
#
#       Target_07_LogLoss  Target_90_LogLoss  Target_120_LogLoss  \
# 0                     0                  0                   0
# 1                     0                  0                   0
# 2                     0                  0                   0
# 3                     0                  0                   0
# 4                     0                  0                   0
# ...                 ...                ...                 ...
# 5616                  0                  0                   0
# 5617                  0                  0                   0
# 5618                  0                  0                   0
# 5619                  0                  0                   0
# 5620                  0                  0                   0
#
#       Target_LogLoss  Target_AUC
# 0           0.000702    0.000702
# 1           0.003880    0.003880
# 2           0.840726    0.840726
# 3           0.628535    0.628535
# 4           0.003471    0.003471
# ...              ...         ...
# 5616        0.000702    0.000702
# 5617        0.000702    0.000702
# 5618        0.000702    0.000702
# 5619        0.000702    0.000702
# 5620        0.000702    0.000702
#
# [5621 rows x 9 columns]

# %%
ss_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-51906734.py in <cell line: 0>()
# ----> 1 ss_
#
# NameError: name 'ss_' is not defined

# %%
from sklearn.metrics import log_loss

# %%
## Compute the log-loss
# loss = log_loss(y_true, y_pred_prob)
# print("LogLoss:", loss)

# loss_ = log_loss(y_true_, y_pred_prob_)
# print("LogLoss:", loss_)

# %%
train_df.columns
# Out:
# Index(['ID', 'farmer_name', 'training_day', 'gender', 'registration', 'age',
#        'group_name', 'belong_to_cooperative', 'county', 'subcounty', 'ward',
#        'adopted_within_07_days', 'adopted_within_90_days',
#        'adopted_within_120_days', 'has_topic_trained_on', 'trainer',
#        'topics_list'],
#       dtype='object')

# %%
train_df_.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2135355370.py in <cell line: 0>()
# ----> 1 train_df_.columns
#
# NameError: name 'train_df_' is not defined
